# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

#  Import and read the charity_data.csv.
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()

# Target variable: IS_SUCCESSFUL
# Feature variables: APPLICATION_TYPE AFFILIATION CLASSIFICATION USE_CASE ORGANIZATION STATUS INCOME_AMT SPECIAL_CONSIDERATIONS ASK_AMT
# Out:
# <ipython-input-1-e87ab43c7c84>:13: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# Displaying the first few rows of application_df to verify the columns were dropped
print(application_df.head())
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()

# Display the number of unique values for each column
print(unique_values)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning

# Display the count of each unique value in the APPLICATION_TYPE column
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()

# Print the counts
print(application_type_counts)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# Define the cutoff point
app_type_cutoff_point = 500

# Identify application types to bin as 'Other'
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < app_type_cutoff_point].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
# Display the count of each unique value in the CLASSIFICATION column
classification_counts = application_df['CLASSIFICATION'].value_counts()

# Print the counts
print(classification_counts)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1

# Filter and display CLASSIFICATION value counts greater than 1
classification_counts_filtered = classification_counts[classification_counts > 1]

# Print the filtered counts
print(classification_counts_filtered)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# Define the cutoff point
class_cutoff_point = 1000

# Identify classifications to bin as 'Other'
classifications_to_replace = application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() < class_cutoff_point].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Or, into custom quantiles
application_df['ASK_AMT_BINNED'] = pd.qcut(application_df['ASK_AMT'], q=[0, .2, .4, .6, .8, 1])
df.drop(columns=['ASK_AMT'], inplace=True)

print(application_df)

# %%
# Convert categorical data to numeric with `pd.get_dummies`

# Encoding categorical variables using pd.get_dummies()
application_df_encoded = pd.get_dummies(application_df, drop_first=True)

# Display the first few rows of the encoded dataframe to verify the encoding
application_df_encoded.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  ORGANIZATION_Trust  \
# 0                    0                    0  ...                   0
# 1                    0                    0  ...                   0
# 2                    0                    0  ...                   0
# 3                    0                    0  ...                   1
# 4                    0                    0  ...                   1
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                  0                       0                         0
# 1                  1                       0                         0
# 2                  0                       0                         0
# 3                  0                       1                         0
# 4                  0                       0                         1
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   0                 0                       0
# 1                   0                 0                       0
# 2                   0                 0                       0
# 3                   0                 0                       0
# 4                   0                 0                       0
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_Y
# 0                0                  0                         0
# 1                0                  0                         0
# 2                0                  0                         0
# 3                0                  0                         0
# 4                0                  0                         0
#
# [5 rows x 37 columns]

# %%
# Check for potential class imbalances
print(application_df_encoded['IS_SUCCESSFUL'].value_counts())
# Out:
# 1    18261
# 0    16038
# Name: IS_SUCCESSFUL, dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
feature_names = application_df_encoded.drop('IS_SUCCESSFUL', axis=1).columns.tolist() #Feature names array
X = application_df_encoded.drop('IS_SUCCESSFUL', axis=1).values  # Features array
y = application_df_encoded['IS_SUCCESSFUL'].values  # Target array

print(X.shape)  # Should show (number_of_samples, number_of_features)
print(y.shape)  # Should show (number_of_samples,)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69420)

print(X_train.shape)  # Should show (number_of_samples, number_of_features)
print(y_train.shape)  # Should show (number_of_samples,)

# Use synthetic minority oversampling to adjust for class imbalance
smote = SMOTE(random_state=42069)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Verify the split
print(f"X_train shape (with SMOTE): {X_train_smote.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape (with SMOTE): {y_train_smote.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# (34299, 36)
# (34299,)
# (27439, 36)
# (27439,)
# X_train shape (with SMOTE): (29340, 36)
# X_test shape: (6860, 36)
# y_train shape (with SMOTE): (29340,)
# y_test shape: (6860,)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler to oversampled data
X_scaler = scaler.fit(X_train_smote)

# Scale the data
X_train_scaled = X_scaler.transform(X_train_smote)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.


# Number of input features
n_features = X_train_smote.shape[1]

# Create the Sequential model
nn = Sequential()

# Input adjusted layer
nn.add(Dense(units=128, activation='relu', input_shape=(n_features,)))
Dropout(0.3),  # Dropout 30% of the neurons in the layer

# First adjusted hidden layer
nn.add(Dense(units=64, activation='relu'))
Dropout(0.3),  # Again, dropout 30% of the neurons

# Second adjusted hidden layer
nn.add(Dense(units=32, activation='relu'))
Dropout(0.3),  # Again, dropout 30% of the neurons

# Output layer
nn.add(Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               4736
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 15105 (59.00 KB)
# Trainable params: 15105 (59.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model with a learning rate schedule
# For a binary classification problem, use 'binary_crossentropy' as the loss function
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# Define the learning rate schedule
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

# Initialize the Adam optimizer with the learning rate schedule
optimizer = Adam(learning_rate=lr_schedule)

# Compile the model with the custom optimizer
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Calculate the save_freq in terms of total steps for 5 epochs
batch_size = 32
steps_per_epoch = len(X_train_smote) // batch_size  # This calculates how many batches (steps) per epoch

# Save every 5 epochs (if you have a different batch size or training configuration, adjust accordingly)
save_freq = steps_per_epoch * 5

# Create the callback for saving the model's weights
cp_callback = ModelCheckpoint(
    filepath="optimization_training_checkpoints/cp-{epoch:04d}.ckpt",
    verbose=1,
    save_weights_only=True,
    save_freq=save_freq)  # Use save_freq with calculated value

# Train the model
epochs = 100  # Set the total number of epochs to train for
history = nn.fit(
    X_train_scaled,
    y_train_smote,
    epochs=epochs,
    validation_split=0.2,  # Use part of the training data for validation
    callbacks=[cp_callback])  # Pass the callback to save weights
# Out:
# Epoch 1/100
# 734/734 [==============================] - 4s 3ms/step - loss: 0.5721 - accuracy: 0.7173 - val_loss: 0.5969 - val_accuracy: 0.7072
# Epoch 2/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5558 - accuracy: 0.7280 - val_loss: 0.5484 - val_accuracy: 0.7381
# Epoch 3/100
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5524 - accuracy: 0.7288 - val_loss: 0.5590 - val_accuracy: 0.7299
# Epoch 4/100
# 734/734 [==============================] - 6s 8ms/step - loss: 0.5508 - accuracy: 0.7318 - val_loss: 0.5513 - val_accuracy: 0.7370
# Epoch 5/100
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5501 - accuracy: 0.7310 - val_loss: 0.5669 - val_accuracy: 0.7335
# Epoch 6/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7332 - val_loss: 0.5501 - val_accuracy: 0.7352
# Epoch 7/100
# 165/734 [=====>........................] - ETA: 1s - loss: 0.5484 - accuracy: 0.7331
# Epoch 7: saving model to optimization_training_checkpoints/cp-0007.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7327 - val_loss: 0.5718 - val_accuracy: 0.7164
# Epoch 8/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7334 - val_loss: 0.5576 - val_accuracy: 0.7316
# Epoch 9/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7343 - val_loss: 0.5467 - val_accuracy: 0.7302
# Epoch 10/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5457 - accuracy: 0.7334 - val_loss: 0.5550 - val_accuracy: 0.7342
# Epoch 11/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7341 - val_loss: 0.5439 - val_accuracy: 0.7328
# Epoch 12/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7342 - val_loss: 0.5613 - val_accuracy: 0.7280
# Epoch 13/100
# 340/734 [============>.................] - ETA: 0s - loss: 0.5413 - accuracy: 0.7360
# Epoch 13: saving model to optimization_training_checkpoints/cp-0013.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7351 - val_loss: 0.5642 - val_accuracy: 0.7275
# Epoch 14/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7352 - val_loss: 0.5491 - val_accuracy: 0.7301
# Epoch 15/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7353 - val_loss: 0.5655 - val_accuracy: 0.7267
# Epoch 16/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7361 - val_loss: 0.5610 - val_accuracy: 0.7268
# Epoch 17/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7359 - val_loss: 0.5682 - val_accuracy: 0.7268
# Epoch 18/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5422 - accuracy: 0.7362 - val_loss: 0.5614 - val_accuracy: 0.7267
# Epoch 19/100
# 519/734 [====================>.........] - ETA: 0s - loss: 0.5409 - accuracy: 0.7374
# Epoch 19: saving model to optimization_training_checkpoints/cp-0019.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7370 - val_loss: 0.5644 - val_accuracy: 0.7209
# Epoch 20/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7379 - val_loss: 0.5644 - val_accuracy: 0.7253
# Epoch 21/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7367 - val_loss: 0.5646 - val_accuracy: 0.7260
# Epoch 22/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7356 - val_loss: 0.5613 - val_accuracy: 0.7270
# Epoch 23/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7365 - val_loss: 0.5683 - val_accuracy: 0.7277
# Epoch 24/100
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5406 - accuracy: 0.7370 - val_loss: 0.5662 - val_accuracy: 0.7221
# Epoch 25/100
# 699/734 [===========================>..] - ETA: 0s - loss: 0.5394 - accuracy: 0.7379
# Epoch 25: saving model to optimization_training_checkpoints/cp-0025.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7379 - val_loss: 0.5789 - val_accuracy: 0.7234
# Epoch 26/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7368 - val_loss: 0.5585 - val_accuracy: 0.7238
# Epoch 27/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7389 - val_loss: 0.5630 - val_accuracy: 0.7258
# Epoch 28/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7385 - val_loss: 0.5657 - val_accuracy: 0.7175
# Epoch 29/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7376 - val_loss: 0.5713 - val_accuracy: 0.7258
# Epoch 30/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7377 - val_loss: 0.5708 - val_accuracy: 0.7232
# Epoch 31/100
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5387 - accuracy: 0.7382 - val_loss: 0.5679 - val_accuracy: 0.7270
# Epoch 32/100
# 117/734 [===>..........................] - ETA: 1s - loss: 0.5411 - accuracy: 0.7284
# Epoch 32: saving model to optimization_training_checkpoints/cp-0032.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7368 - val_loss: 0.5910 - val_accuracy: 0.7224
# Epoch 33/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7389 - val_loss: 0.5749 - val_accuracy: 0.7229
# Epoch 34/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7388 - val_loss: 0.5746 - val_accuracy: 0.7232
# Epoch 35/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7376 - val_loss: 0.5752 - val_accuracy: 0.7236
# Epoch 36/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7387 - val_loss: 0.5625 - val_accuracy: 0.7253
# Epoch 37/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7386 - val_loss: 0.5673 - val_accuracy: 0.7244
# Epoch 38/100
# 315/734 [===========>..................] - ETA: 1s - loss: 0.5410 - accuracy: 0.7356
# Epoch 38: saving model to optimization_training_checkpoints/cp-0038.ckpt
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5372 - accuracy: 0.7385 - val_loss: 0.5674 - val_accuracy: 0.7263
# Epoch 39/100
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5372 - accuracy: 0.7394 - val_loss: 0.5675 - val_accuracy: 0.7253
# Epoch 40/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7389 - val_loss: 0.5717 - val_accuracy: 0.7239
# Epoch 41/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7382 - val_loss: 0.5652 - val_accuracy: 0.7282
# Epoch 42/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7391 - val_loss: 0.5774 - val_accuracy: 0.7229
# Epoch 43/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7388 - val_loss: 0.5774 - val_accuracy: 0.7248
# Epoch 44/100
# 483/734 [==================>...........] - ETA: 0s - loss: 0.5361 - accuracy: 0.7399
# Epoch 44: saving model to optimization_training_checkpoints/cp-0044.ckpt
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5370 - accuracy: 0.7401 - val_loss: 0.5776 - val_accuracy: 0.7243
# Epoch 45/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5361 - accuracy: 0.7390 - val_loss: 0.5823 - val_accuracy: 0.7277
# Epoch 46/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7381 - val_loss: 0.5797 - val_accuracy: 0.7241
# Epoch 47/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7391 - val_loss: 0.5859 - val_accuracy: 0.7231
# Epoch 48/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7388 - val_loss: 0.5749 - val_accuracy: 0.7243
# Epoch 49/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7396 - val_loss: 0.5872 - val_accuracy: 0.7226
# Epoch 50/100
# 669/734 [==========================>...] - ETA: 0s - loss: 0.5356 - accuracy: 0.7374
# Epoch 50: saving model to optimization_training_checkpoints/cp-0050.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7381 - val_loss: 0.5938 - val_accuracy: 0.7212
# Epoch 51/100
# 734/734 [==============================] - 3s 5ms/step - loss: 0.5353 - accuracy: 0.7400 - val_loss: 0.5866 - val_accuracy: 0.7249
# Epoch 52/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7403 - val_loss: 0.5830 - val_accuracy: 0.7258
# Epoch 53/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7379 - val_loss: 0.5870 - val_accuracy: 0.7229
# Epoch 54/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7385 - val_loss: 0.5960 - val_accuracy: 0.7248
# Epoch 55/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7386 - val_loss: 0.5852 - val_accuracy: 0.7253
# Epoch 56/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7402 - val_loss: 0.5764 - val_accuracy: 0.7285
# Epoch 57/100
# 114/734 [===>..........................] - ETA: 1s - loss: 0.5224 - accuracy: 0.7522
# Epoch 57: saving model to optimization_training_checkpoints/cp-0057.ckpt
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5350 - accuracy: 0.7399 - val_loss: 0.5886 - val_accuracy: 0.7232
# Epoch 58/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5362 - accuracy: 0.7391 - val_loss: 0.5756 - val_accuracy: 0.7273
# Epoch 59/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7393 - val_loss: 0.5836 - val_accuracy: 0.7246
# Epoch 60/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7401 - val_loss: 0.5735 - val_accuracy: 0.7273
# Epoch 61/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7399 - val_loss: 0.5812 - val_accuracy: 0.7267
# Epoch 62/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7391 - val_loss: 0.5947 - val_accuracy: 0.7249
# Epoch 63/100
# 277/734 [==========>...................] - ETA: 0s - loss: 0.5312 - accuracy: 0.7404
# Epoch 63: saving model to optimization_training_checkpoints/cp-0063.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7402 - val_loss: 0.5978 - val_accuracy: 0.7249
# Epoch 64/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7402 - val_loss: 0.5793 - val_accuracy: 0.7270
# Epoch 65/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7399 - val_loss: 0.5920 - val_accuracy: 0.7244
# Epoch 66/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7394 - val_loss: 0.5722 - val_accuracy: 0.7246
# Epoch 67/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7395 - val_loss: 0.5768 - val_accuracy: 0.7243
# Epoch 68/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7403 - val_loss: 0.5899 - val_accuracy: 0.7267
# Epoch 69/100
# 466/734 [==================>...........] - ETA: 0s - loss: 0.5310 - accuracy: 0.7383
# Epoch 69: saving model to optimization_training_checkpoints/cp-0069.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7393 - val_loss: 0.5750 - val_accuracy: 0.7253
# Epoch 70/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7405 - val_loss: 0.5824 - val_accuracy: 0.7248
# Epoch 71/100
# 734/734 [==============================] - 3s 4ms/step - loss: 0.5336 - accuracy: 0.7394 - val_loss: 0.5811 - val_accuracy: 0.7239
# Epoch 72/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7406 - val_loss: 0.5874 - val_accuracy: 0.7246
# Epoch 73/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7404 - val_loss: 0.5797 - val_accuracy: 0.7249
# Epoch 74/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7395 - val_loss: 0.5866 - val_accuracy: 0.7243
# Epoch 75/100
# 626/734 [========================>.....] - ETA: 0s - loss: 0.5284 - accuracy: 0.7424
# Epoch 75: saving model to optimization_training_checkpoints/cp-0075.ckpt
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7399 - val_loss: 0.5755 - val_accuracy: 0.7270
# Epoch 76/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7398 - val_loss: 0.5858 - val_accuracy: 0.7248
# Epoch 77/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7399 - val_loss: 0.5868 - val_accuracy: 0.7249
# Epoch 78/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5328 - accuracy: 0.7399 - val_loss: 0.5852 - val_accuracy: 0.7249
# Epoch 79/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7391 - val_loss: 0.5679 - val_accuracy: 0.7268
# Epoch 80/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7399 - val_loss: 0.5910 - val_accuracy: 0.7253
# Epoch 81/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7407 - val_loss: 0.5862 - val_accuracy: 0.7234
# Epoch 82/100
#  59/734 [=>............................] - ETA: 1s - loss: 0.5198 - accuracy: 0.7511
# Epoch 82: saving model to optimization_training_checkpoints/cp-0082.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7407 - val_loss: 0.5794 - val_accuracy: 0.7261
# Epoch 83/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7400 - val_loss: 0.5903 - val_accuracy: 0.7258
# Epoch 84/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7402 - val_loss: 0.5959 - val_accuracy: 0.7263
# Epoch 85/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7391 - val_loss: 0.6245 - val_accuracy: 0.7212
# Epoch 86/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7402 - val_loss: 0.5822 - val_accuracy: 0.7263
# Epoch 87/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7399 - val_loss: 0.5819 - val_accuracy: 0.7272
# Epoch 88/100
# 255/734 [=========>....................] - ETA: 0s - loss: 0.5288 - accuracy: 0.7393
# Epoch 88: saving model to optimization_training_checkpoints/cp-0088.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7401 - val_loss: 0.5850 - val_accuracy: 0.7244
# Epoch 89/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7404 - val_loss: 0.6025 - val_accuracy: 0.7236
# Epoch 90/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7402 - val_loss: 0.5918 - val_accuracy: 0.7243
# Epoch 91/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5326 - accuracy: 0.7408 - val_loss: 0.5925 - val_accuracy: 0.7209
# Epoch 92/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5326 - accuracy: 0.7396 - val_loss: 0.5881 - val_accuracy: 0.7227
# Epoch 93/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7396 - val_loss: 0.5937 - val_accuracy: 0.7246
# Epoch 94/100
# 436/734 [================>.............] - ETA: 0s - loss: 0.5328 - accuracy: 0.7399
# Epoch 94: saving model to optimization_training_checkpoints/cp-0094.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7406 - val_loss: 0.5990 - val_accuracy: 0.7243
# Epoch 95/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7405 - val_loss: 0.5810 - val_accuracy: 0.7248
# Epoch 96/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7410 - val_loss: 0.5960 - val_accuracy: 0.7241
# Epoch 97/100
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7412 - val_loss: 0.5815 - val_accuracy: 0.7236
# Epoch 98/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7404 - val_loss: 0.5900 - val_accuracy: 0.7265
# Epoch 99/100
# 734/734 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7403 - val_loss: 0.5904 - val_accuracy: 0.7219
# Epoch 100/100
# 599/734 [=======================>......] - ETA: 0s - loss: 0.5340 - accuracy: 0.7379
# Epoch 100: saving model to optimization_training_checkpoints/cp-0100.ckpt
# 734/734 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7395 - val_loss: 0.5921 - val_accuracy: 0.7256

# %%
# Report baseline accuracy
test_loss, test_accuracy = nn.evaluate(X_test_scaled, y_test)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.7238
# Test Accuracy: 0.7237609624862671

# %%
# Use automated hyperparamter tuning (Hyperband) to find optimal model hyperparameters
from kerastuner.tuners import Hyperband

def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(units=hp.Int('units_input', min_value=32, max_value=512, step=32),
                           activation=hp.Choice('activation_input', ['relu', 'tanh', 'elu']),
                           input_shape=(n_features,)))
    model.add(layers.Dropout(0.3))
    for i in range(hp.Int('num_layers', 1, 3)):
        model.add(layers.Dense(units=hp.Int(f'units_layer_{i}', min_value=32, max_value=512, step=32),
                               activation=hp.Choice(f'activation_layer_{i}', ['relu', 'tanh', 'elu'])))
        model.add(layers.Dropout(0.3))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(optimizer=keras.optimizers.Adam(
        hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])

    return model

# Initialize the Hyperband tuner
tuner = Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=25,
    directory='hyperband_tuning',
    project_name='tune_units_layers_activation'
)

# Start the search for the best hyperparameter configuration
tuner.search(X_train_scaled, y_train_smote, epochs=10, validation_split=0.2)

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"The best number of units in the first layer is {best_hps.get('units_input')}.")
for i in range(best_hps.get('num_layers')):
    print(f"The best number of units in layer {i+1} is {best_hps.get(f'units_layer_{i}')}, with activation function {best_hps.get(f'activation_layer_{i}')}.")
print(f"The best learning rate for the optimizer is {best_hps.get('learning_rate')}.")
# Out:
# Trial 30 Complete [00h 01m 18s]
# val_accuracy: 0.7384117245674133
#
# Best val_accuracy So Far: 0.7450579404830933
# Total elapsed time: 00h 19m 08s
# The best number of units in the first layer is 512.
# The best number of units in layer 1 is 96, with activation function tanh.
# The best number of units in layer 2 is 416, with activation function relu.
# The best number of units in layer 3 is 64, with activation function elu.
# The best learning rate for the optimizer is 0.001.

# %%
best_model = tuner.get_best_models(num_models=1)[0]
test_loss_tuned, test_accuracy_tuned = best_model.evaluate(X_test_scaled, y_test)
print(f"Test Loss: {test_loss_tuned}, Test Accuracy: {test_accuracy_tuned}")
# Out:
# 215/215 [==============================] - 1s 2ms/step - loss: 0.5619 - accuracy: 0.7245
# Test Loss: 0.5618760585784912, Test Accuracy: 0.7244898080825806

# %%
# Save best model
best_model.save('AlphabetSoupCharity_Optimization.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
